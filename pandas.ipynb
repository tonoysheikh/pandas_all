# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Empty DataFrame

# %%
city = ["dhaka","kishoreganj","chandpur","feni"]
city
# Out:
# ['dhaka', 'kishoreganj', 'chandpur', 'feni']

# %%
df = pd.DataFrame(city)
df
# Out:
#              0
# 0        dhaka
# 1  kishoreganj
# 2     chandpur
# 3         feni

# %%
type(city)
# Out:
# list

# %%
row,col = df.shape

# %%
row , col
# Out:
# (4, 1)

# %%
df.shape
# Out:
# (4, 1)

# %%
df = pd.DataFrame(city, columns = ['BD city List'])
df
# Out:
#   BD city List
# 0        dhaka
# 1  kishoreganj
# 2     chandpur
# 3         feni

# %%
city2 = ["Rampura","Itna","sadar","sadar"]
df2 = pd.DataFrame(zip(city,city2) , columns = ["District" , "Towns"])
df2
# Out:
#       District    Towns
# 0        dhaka  Rampura
# 1  kishoreganj     Itna
# 2     chandpur    sadar
# 3         feni    sadar

# %%
df2.shape
# Out:
# (4, 2)

# %%
city5 = ['c1','c2','c3']
city6 = ['c4','c5','c6']

# %%
dict = {
    "city3" : city5 ,
    "city4" : city6
}

# %%
dict
# Out:
# {'city3': ['c1', 'c2', 'c3'], 'city4': ['c4', 'c5', 'c6']}

# %%
df3 = pd.DataFrame(dict)
df3
# Out:
#   city3 city4
# 0    c1    c4
# 1    c2    c5
# 2    c3    c6

# %%
df4 = pd.read_csv("/content/sample_data/california_housing_train.csv")
df4
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
df4.tail()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0

# %%
df4.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
df4.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
# 5    -114.58     33.63                29.0       1387.0           236.0
# 6    -114.58     33.61                25.0       2907.0           680.0
# 7    -114.59     34.83                41.0        812.0           168.0
# 8    -114.59     33.61                34.0       4789.0          1175.0
# 9    -114.60     34.83                46.0       1497.0           309.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# ...

# %%
df4.values
# Out:
# array([[-1.1431e+02,  3.4190e+01,  1.5000e+01, ...,  4.7200e+02,
#          1.4936e+00,  6.6900e+04],
#        [-1.1447e+02,  3.4400e+01,  1.9000e+01, ...,  4.6300e+02,
#          1.8200e+00,  8.0100e+04],
#        [-1.1456e+02,  3.3690e+01,  1.7000e+01, ...,  1.1700e+02,
#          1.6509e+00,  8.5700e+04],
#        ...,
#        [-1.2430e+02,  4.1840e+01,  1.7000e+01, ...,  4.5600e+02,
#          3.0313e+00,  1.0360e+05],
#        [-1.2430e+02,  4.1800e+01,  1.9000e+01, ...,  4.7800e+02,
#          1.9797e+00,  8.5800e+04],
#        [-1.2435e+02,  4.0540e+01,  5.2000e+01, ...,  2.7000e+02,
#          3.0147e+00,  9.4600e+04]])

# %%
df4.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %%
df4['total_rooms']
# Out:
# 0        5612.0
# 1        7650.0
# 2         720.0
# 3        1501.0
# 4        1454.0
#           ...
# 16995    2217.0
# 16996    2349.0
# 16997    2677.0
# 16998    2672.0
# 16999    1820.0
# Name: total_rooms, Length: 17000, dtype: float64
